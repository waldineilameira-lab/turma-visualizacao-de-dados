# %%
'''
re.search()     # procura por um padrão dentro de uma string
re.findall()    # procura por um padrão dentro de uma string e retorna todas as ocorrências
re.sub()        # substitui um padrão por outro dentro de uma string
re.match()      # verifica se o início de uma string corresponde a um padrão
re.split()      # divide uma string em uma lista usando um padrão como delimitador

'''

import pandas as pd
import re

URL = ("alunos/orlando_castro/semana_04/bases/base_rh.csv")
