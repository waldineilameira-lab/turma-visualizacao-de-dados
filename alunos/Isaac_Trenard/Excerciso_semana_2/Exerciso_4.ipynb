# %% [markdown]
# Sistema de gestão escolar -- Escola os pequenos Analistas --

# %%
# 0. Para rodar o programos iniciamos com um codigo que poderia ser a base do conceito Sistema de gestão escolar
quantos_alunos_cadastrados = int(input('Por favor insira o numero de alunos matriculados'))

# 1. Agora vamos personalizar esse sistema escolar com os dados relevantes dos alunos ---

nome_do_aluno = str(input('Por favor digite o nome do aluno = '))
idade_do_aluno = int(input('Digite a sua idade'))

#Criamos a funtion através do def para saber suas notas
def calcular_media_ano_escolar ():
    nota_primeiro_trimestre = float(input('Digite a sua nota 1ro trimestre'))
    nota_segundo_trimestre = float(input('Digite a sua nota 2do trimestre'))
    nota_terceiro_trimestre = float(input('Digite a sua nota 3ro trimestre'))

    if nota_primeiro_trimestre <0 or nota_segundo_trimestre <0 or nota_terceiro_trimestre <0:
        print('Ñota inválida contate com a sua cordenação')
    media = (nota_primeiro_trimestre + nota_segundo_trimestre + nota_terceiro_trimestre) /3
    return print(f'A media das nota do aluno: {nome_do_aluno} é de {media:.2f}')
calcular_media_ano_escolar()


# Analises escolar para saber o momento do aluno
media = calcular_media_ano_escolar()

if media >=7:
    print ('Aprovado!')
elif 5 <= media <7:
    print('Recuperação')
elif media <5:
    print('Reprovado')

if idade_do_aluno <= 15 and media >=7:
    print('Destaque Jovem')
    print(True)    

# 2. Para que realmente seja um ~sistema que rode uma e outra vez~ criamos um loop através de for i
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[22], line 2
#       1 # 0. Para rodar o programos iniciamos com um codigo que poderia ser a base do conceito Sistema de gestão escolar
# ----> 2 quantos_alunos_cadastrados = int(input('Por favor insira o numero de alunos matriculados'))
#       3
#       4 # 1. Agora vamos personalizar esse sistema escolar com os dados relevantes dos alunos ---
#       5
#
# ValueError: invalid literal for int() with base 10: 'isaac'
