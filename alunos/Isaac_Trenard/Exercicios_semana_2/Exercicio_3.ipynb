# %% [markdown]
# Sistema de clasificação de IMC
#
# # Crie um programa que calcule o IMC de uma pessoa e classifique o resultado

# %%
nome_do_Paciente = str(input('Por favor, digite seu nome e sobrenome'))
idade_do_Paciente = int(input('Por favor, digite a sua idade'))
peso_do_Paciente = float(input('Digite seu peso exato com gramas'))
altura_do_Paciente = float (input('Digite sua altura'))
calculo_IMC = peso_do_Paciente / (altura_do_Paciente**2)
print(f'O paciente informou os seguintes dados para calculos de INDICE DE MASA CORPORAL')
print (f' Nome do Paciente : {nome_do_Paciente} ')
print (f' Idade do Paciente : {idade_do_Paciente} ')
print (f' Peso do Paciente : {peso_do_Paciente:.3f} ')
print (f' Altura do Paciente : {altura_do_Paciente:.2f} ')
print (f' O calculo foi feito e deú como resultado que o IMC do paciente foi : {calculo_IMC:.2f} ')
print (f' Seguem abaixo as seguintes informações do analisis médico: ')

if calculo_IMC <= 18.5:
    print('Abaixo do peso saudavel')
elif 18.5 <= calculo_IMC >= 24.9:
    print('Peso normal')
elif 25.0 <= calculo_IMC >= 29.9:
    print('Voce esta com Sobrepeso')
elif 30.0 <= calculo_IMC >= 34.9:
    print('Obesidade grau 1')
elif 35.0 <= calculo_IMC >= 39.9:
    print('Obesidade grau 2')
elif calculo_IMC >= 40.0:
    print('Obesidade grau 3')

if calculo_IMC <= 24.9 and idade_do_Paciente >= 60:
    print('Você esta numa idade com alto risco de sobrepeso, porfavor coma saudavel')
paciente_saudavel = calculo_IMC <= 25.0
print(paciente_saudavel)
# Out:
# O paciente informou os seguintes dados para calculos de INDICE DE MASA CORPORAL
#  Nome do Paciente : Isaac Trenard
#  Idade do Paciente : 60
#  Peso do Paciente : 80.000
#  Altura do Paciente : 1.40
#  O calculo foi feito e deú como resultado que o IMC do paciente foi : 40.82
#  Seguem abaixo as seguintes informações do analisis médico:
# Peso normal
# False
