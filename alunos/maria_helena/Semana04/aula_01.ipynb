# %%
#importar biblioteca pandas e abrir o arquivo csv:
import pandas as pd

caminho_local = r"C:\Users\DELL\OneDrive\Documentos\MH\SCTec\turma-visualizacao-de-dados\alunos\maria_helena\Semana04\base_rh.csv"

df = pd.read_csv(caminho_local, sep=";", encoding="cp1252", decimal=",")

#imprimir informações sobre o DataFrame:
print(f"Shape: {df.shape}")
print(f"\nTipos:\n{df.dtypes}")
print(f"\nPrimeiras 3 linhas:\n{df.head(3).to_string()}")
# Out:
# Shape: (1000, 10)
#
# Tipos:
# ID_Funcionario      int64
# Nome                  str
# Departamento          str
# Cargo                 str
# Salario           float64
# Data_Admissao         str
# Genero                str
# Idade               int64
# Estado_Civil          str
# Status                str
# dtype: object
#
# Primeiras 3 linhas:
#    ID_Funcionario                 Nome Departamento        Cargo   Salario Data_Admissao Genero  Idade Estado_Civil   Status
# 0               1          Julia Nunes    Logística  Coordenador   9088.34    13/08/2024      F     43     Solteiro  Inativo
# 1               2   Sr. Gustavo Duarte           TI      Gerente   8155.98    29/04/2017      F     59     Solteiro  Inativo
# 2               3  Srta. Mariana Cunha           RH  Coordenador  14027.93    11/12/2024      F     27   Divorciado    Ativo

# %%
#verificar dimensões do dataframe:
print(f"Shape: {df.shape}")
print(f"Linhas: {df.shape[0]}")
print(f"Colunas: {df.shape[1]}")
print(f"\nNomes das colunas:\n{df.columns.tolist()}")
# Out:
# Shape: (1000, 10)
# Linhas: 1000
# Colunas: 10
#
# Nomes das colunas:
# ['ID_Funcionario', 'Nome', 'Departamento', 'Cargo', 'Salario', 'Data_Admissao', 'Genero', 'Idade', 'Estado_Civil', 'Status']

# %%
#verificar tipos de dados:
print(f"\nTipos:\n{df.dtypes}")
# Out:
# Tipos:
# ID_Funcionario      int64
# Nome                  str
# Departamento          str
# Cargo                 str
# Salario           float64
# Data_Admissao         str
# Genero                str
# Idade               int64
# Estado_Civil          str
# Status                str
# dtype: object

# %%
#mostrar informações das linhas:
print(f"\nPrimeiras 3 linhas:\n{df.head(3).to_string()}")
print(f"\nÚltimas 3 linhas:\n{df.tail(3).to_string()}")

#exemplo: mostrar informações sobre determinada linha
print(f"\nPrimeira linha:\n{df.iloc[0].to_string()}")
# Out:
# Primeiras 3 linhas:
#    ID_Funcionario                 Nome Departamento        Cargo   Salario Data_Admissao Genero  Idade Estado_Civil   Status
# 0               1          Julia Nunes    Logística  Coordenador   9088.34    13/08/2024      F     43     Solteiro  Inativo
# 1               2   Sr. Gustavo Duarte           TI      Gerente   8155.98    29/04/2017      F     59     Solteiro  Inativo
# 2               3  Srta. Mariana Cunha           RH  Coordenador  14027.93    11/12/2024      F     27   Divorciado    Ativo
#
# Últimas 3 linhas:
#      ID_Funcionario                Nome Departamento     Cargo   Salario Data_Admissao Genero  Idade Estado_Civil   Status
# 997             998   Isabelly Ferreira           TI   Gerente   2348.73    29/12/2023      F     58     Solteiro  Inativo
# 998             999       Thales Farias     Produção  Analista   9430.62    25/12/2019      M     41     Solteiro    Ativo
# 999            1000  Sra. Maysa Costela     Produção   Técnico  12549.72    14/11/2022      M     46        Viúvo  Inativo
#
# Primeira linha:
# ID_Funcionario              1
# Nome              Julia Nunes
# Departamento        Logística
# Cargo             Coordenador
# Salario               9088.34
# Data_Admissao      13/08/2024
# Genero                      F
# Idade                      43
# Estado_Civil         Solteiro
# Status                Inativo

# %%
#verificar informações gerais do DataFrame (se há colunas com valores nulos, tipo de dados, etc):
print(df.info())
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   ID_Funcionario  1000 non-null   int64
#  1   Nome            1000 non-null   str
#  2   Departamento    1000 non-null   str
#  3   Cargo           1000 non-null   str
#  4   Salario         1000 non-null   float64
#  5   Data_Admissao   1000 non-null   str
#  6   Genero          1000 non-null   str
#  7   Idade           1000 non-null   int64
#  8   Estado_Civil    1000 non-null   str
#  9   Status          1000 non-null   str
# dtypes: float64(1), int64(2), str(7)
# memory usage: 78.3 KB

# %%
#verificar a quantidade de nulos por coluna:
print("\nNulos por coluna:")
print(df.isnull().sum())
# Out:
# Nulos por coluna:
# ID_Funcionario    0
# Nome              0
# Departamento      0
# Cargo             0
# Salario           0
# Data_Admissao     0
# Genero            0
# Idade             0
# Estado_Civil      0
# Status            0
# dtype: int64

# %%
#verificar o percentual de dados nulos:
print("\n% de nulos:")
print((df.isnull().sum() / len(df) * 100).round(2))
# Out:
# % de nulos:
# ID_Funcionario    0.0
# Nome              0.0
# Departamento      0.0
# Cargo             0.0
# Salario           0.0
# Data_Admissao     0.0
# Genero            0.0
# Idade             0.0
# Estado_Civil      0.0
# Status            0.0
# dtype: float64

# %%
#verificar dados estatísticos das colunas (.describe()):
# count, mean, std, min, 25%, 50%, 75%, max
print(df.describe().round(2))
# Out:
#        ID_Funcionario   Salario    Idade
# count         1000.00   1000.00  1000.00
# mean           500.50   8579.95    41.40
# std            288.82   3657.37    13.67
# min              1.00   2000.71    18.00
# 25%            250.75   5564.54    30.00
# 50%            500.50   8571.13    41.00
# 75%            750.25  11554.63    53.00
# max           1000.00  14954.51    65.00

# %%
#verificar a quantidade de valores diferentes existem por coluna — identifica colunas categóricas:
print("Valores únicos por coluna:")
print(df.nunique())
# Out:
# Valores únicos por coluna:
# ID_Funcionario    1000
# Nome               976
# Departamento         6
# Cargo                5
# Salario           1000
# Data_Admissao      878
# Genero               2
# Idade               48
# Estado_Civil         4
# Status               2
# dtype: int64

# %%
#verificar quais são os valores da distribuição de cada coluna especificadamente:
for col in ["Departamento", "Cargo", "Genero", "Status", "Estado_Civil"]:
    print(f"\n── {col} ──")
    print(df[col].value_counts())
# Out:
# ── Departamento ──
# Departamento
# Financeiro    189
# Produção      182
# RH            166
# Vendas        160
# Logística     156
# TI            147
# Name: count, dtype: int64
#
# ── Cargo ──
# Cargo
# Coordenador    225
# Gerente        221
# Assistente     199
# Analista       178
# Técnico        177
# Name: count, dtype: int64
#
# ── Genero ──
# Genero
# F    510
# M    490
# Name: count, dtype: int64
#
# ── Status ──
# Status
# Ativo      515
# Inativo    485
# Name: count, dtype: int64
#
# ── Estado_Civil ──
# Estado_Civil
# Solteiro      265
# Viúvo         261
# Divorciado    240
# Casado        234
# Name: count, dtype: int64

# %%
#filtrar em 3 colunas (filtro composto) e mostrar as 4 primeiras linhas:
print(df[["Nome", "Departamento", "Salario"]].head(4))
# Out:
#                   Nome Departamento   Salario
# 0          Julia Nunes    Logística   9088.34
# 1   Sr. Gustavo Duarte           TI   8155.98
# 2  Srta. Mariana Cunha           RH  14027.93
# 3   Ana Sophia da Cruz     Produção   6647.97

# %%
# Filtro simples (apenas 1 coluna): apenas funcionários Ativos
ativos = df[df["Status"] == "Ativo"]
print(f"Ativos: {len(ativos)} | Inativos: {len(df) - len(ativos)}")

# Filtro composto (2 ou mais colunas): Gerentes do departamento de TI
gerentes_ti = df[(df["Cargo"] == "Gerente") & (df["Departamento"] == "TI")]
print(f"\nGerentes de TI:")
print(gerentes_ti[["Nome", "Salario", "Status"]].to_string(index=False))
# Out:
# Ativos: 515 | Inativos: 485
#
# Gerentes de TI:
#                        Nome  Salario  Status
#          Sr. Gustavo Duarte  8155.98 Inativo
#           Benjamin da Costa  9766.01 Inativo
#            Catarina Costela  9597.83 Inativo
#               Laura Cardoso  7364.46 Inativo
#               Maria Cardoso 12127.27 Inativo
#           Ana Júlia Cardoso  8738.63   Ativo
#                 Ian Pereira  2395.32   Ativo
#           Ana Clara Peixoto  7301.14   Ativo
#              Augusto Santos  8237.80 Inativo
#             Manuela Barbosa  7015.91   Ativo
#            Antônio Oliveira  5273.24   Ativo
#         Luiz Gustavo da Luz  2543.19 Inativo
#                Stella Costa 11718.30   Ativo
#               Bryan da Cruz 11790.21   Ativo
#              Emilly Freitas  5147.62 Inativo
#           Brenda Nascimento  5429.24   Ativo
#                 Sofia Sales  4941.24 Inativo
#             Manuela Cardoso  5305.96 Inativo
#         Luiz Henrique Souza  4398.17   Ativo
#              Bruna da Cunha  3423.93 Inativo
#                Alícia Porto  9547.18 Inativo
#              Bianca da Cruz  7903.06 Inativo
# Sra. Maria Fernanda Freitas  2686.67   Ativo
#             Emanuelly Souza  8305.81 Inativo
#               Olivia Moraes  3124.24 Inativo
#               Bernardo Lima  6149.05   Ativo
#        Sra. Caroline Araújo  6750.44 Inativo
#           Ana Clara Moreira 14523.10   Ativo
#                 Luna Novaes  3106.49 Inativo
#           Valentina Cardoso 10602.13   Ativo
#           Isabelly Ferreira  2348.73 Inativo

# %%
#transformar a base csv em json (melhor para ser trabalhado no tratamento de dados e visualização):
import pandas as pd
import json

# ── Exportar o DataFrame para JSON ───────────────────────────
# orient="records" → cada linha vira um objeto JSON independente
# force_ascii=False → mantém ã é ç sem escapar (\u00e3 etc.)
# indent=2         → arquivo legível por humanos
df.to_json(
    "base_rh.json",
    orient="records",
    force_ascii=False,
    indent=2
)

print("✓ base_rh.json gerado")
# Out:
# ✓ base_rh.json gerado

# %%
# ── Lendo de volta para confirmar ────────────────────────────
df_json = pd.read_json("base_rh.json")
print(f"Linhas lidas do JSON: {len(df_json)}")
# Out:
# Linhas lidas do JSON: 1000

# %%
# ── Visualizar os 2 primeiros registros no formato JSON ───────
with open("base_rh.json", "r", encoding="utf-8") as f:
    amostra = json.load(f)
print("\nPrimeiros 2 registros no JSON:")
print(json.dumps(amostra[:2], ensure_ascii=False, indent=2))
# Out:
# Primeiros 2 registros no JSON:
# [
#   {
#     "ID_Funcionario": 1,
#     "Nome": "Julia Nunes",
#     "Departamento": "Logística",
#     "Cargo": "Coordenador",
#     "Salario": 9088.34,
#     "Data_Admissao": "13/08/2024",
#     "Genero": "F",
#     "Idade": 43,
#     "Estado_Civil": "Solteiro",
#     "Status": "Inativo"
#   },
#   {
#     "ID_Funcionario": 2,
#     "Nome": "Sr. Gustavo Duarte",
#     "Departamento": "TI",
#     "Cargo": "Gerente",
#     "Salario": 8155.98,
#     "Data_Admissao": "29/04/2017",
#     "Genero": "F",
#     "Idade": 59,
#     "Estado_Civil": "Solteiro",
#     "Status": "Inativo"
#   }
# ]

# %%
#transformar o DataFrame em Excel:
import pandas as pd

#baixar openpyxl para exportar para Excel:
# pip install openpyxl

# ── Exportação simples: tudo em uma aba ──────────────────────
df.to_excel("base_rh.xlsx", index=False, sheet_name="Funcionarios")
print("✓ base_rh.xlsx (aba única) gerado")

# ── Exportação avançada: uma aba por departamento ────────────
# ExcelWriter permite escrever múltiplas abas no mesmo arquivo
with pd.ExcelWriter("base_rh_por_depto.xlsx", engine="openpyxl") as writer:

    # Aba 1: dataset completo
    df.to_excel(writer, sheet_name="Todos", index=False)

    # Uma aba para cada departamento
    for depto in df["Departamento"].unique():
        df_depto = df[df["Departamento"] == depto]
        # Nome da aba limitado a 31 chars (limite do Excel)
        nome_aba = depto[:31]
        df_depto.to_excel(writer, sheet_name=nome_aba, index=False)
        print(f"  Aba '{nome_aba}': {len(df_depto)} registros")

print("\n✓ base_rh_por_depto.xlsx gerado")

# ── Lendo de volta uma aba específica ────────────────────────
df_rh = pd.read_excel("base_rh_por_depto.xlsx", sheet_name="RH")
print(f"\nAba RH: {len(df_rh)} funcionários")
print(df_rh[["Nome", "Cargo", "Salario"]].head(4).to_string(index=False))
# Out:
# ✓ base_rh.xlsx (aba única) gerado
#   Aba 'Logística': 156 registros
#   Aba 'TI': 147 registros
#   Aba 'RH': 166 registros
#   Aba 'Produção': 182 registros
#   Aba 'Vendas': 160 registros
#   Aba 'Financeiro': 189 registros
#
# ✓ base_rh_por_depto.xlsx gerado
#
# Aba RH: 166 funcionários
#                Nome       Cargo  Salario
# Srta. Mariana Cunha Coordenador 14027.93
#       Marcela Costa    Analista 12403.42
#   Gabrielly Cardoso    Analista  2728.36
#  Dr. Calebe Barbosa    Analista  3852.93

# %%
#TRATAMENTO DE DATAS (transformar string em data e vice-versa):
#importar biblioteca datetime para trabalhar com datas:
from datetime import datetime, timedelta

# ── TRANSFORMAR STRING EM DATA: strptime: texto → objeto data ─────────────────────────────────────────
# Pegamos o primeiro valor da coluna Data_Admissao como exemplo
data_texto = '13/08/2024'

# datetime.strptime(texto, formato)
# O formato descreve COMO a string está escrita:
# '%d/%m/%Y' = dia/mês/ano
data_obj = datetime.strptime(data_texto, '%d/%m/%Y')

print(f'String original  : "{data_texto}"')
print(f'Objeto datetime  : {data_obj}')
print(f'Tipo             : {type(data_obj)}')
print()

# ── TRANSFORMAR DATA EM STRING:strftime: objeto data → texto formatado ───────────────────────────────
# Agora podemos formatar a data do jeito que quisermos
formatado = data_obj.strftime('%d de %B de %Y')  # 13 de August de 2024
print(f'Formatado        : {formatado}')

# Extraindo partes da data
print(f'Ano              : {data_obj.year}')
print(f'Mês              : {data_obj.month}')
print(f'Dia              : {data_obj.day}')
# Out:
# String original : '13/08/2024'
# Objeto datetime : 2024-08-13 00:00:00
# Tipo            : <class 'datetime.datetime'>
# Formatado       : August de 2024
#
# Hoje            : 13/05/2026
# Diferença       : 638 dias
# Em anos         : 1.7 anos
#
# Tipo após conversão: datetime64[us]
# Valores NaT gerados: 0
#
# Amostra — Data convertida e tempo de casa:
#                Nome Data_Admissao  Tempo_Casa_Anos
#         Julia Nunes    2024-08-13              1.7
#  Sr. Gustavo Duarte    2017-04-29              9.0
# Srta. Mariana Cunha    2024-12-11              1.4
#  Ana Sophia da Cruz    2019-06-16              6.9
#   Dr. Nicolas Pinto    2019-03-29              7.1
#       Marcela Costa    2024-07-23              1.8

# %%
#calcular a diferenca entre duas datas:
# ── timedelta: diferença entre duas datas ────────────────────────────────
# datetime.today() → data e hora de agora
hoje = datetime.today()

# Subtrair duas datas retorna um objeto timedelta
diferenca = hoje - data_obj

print(f'Data de admissão : {data_texto}')
print(f'Hoje             : {hoje.strftime("%d/%m/%Y")}')
print(f'Diferença        : {diferenca.days} dias')
print(f'Em anos          : {diferenca.days / 365.25:.1f} anos')

# Por que 365.25 e não 365?
# Todo 4 anos existe um ano bissexto com 366 dias.
# 365.25 é a média correta: (365 × 3 + 366) / 4 = 365.25
# Out:
# Colunas derivadas criadas:
#                Nome Data_Admissao  Ano_Admissao  Mes_Admissao  Trimestre
#         Julia Nunes    2024-08-13          2024             8          3
#  Sr. Gustavo Duarte    2017-04-29          2017             4          2
# Srta. Mariana Cunha    2024-12-11          2024            12          4
#  Ana Sophia da Cruz    2019-06-16          2019             6          2
#
# Distribuição por faixa de tempo de casa:
# Faixa_Tempo_Casa
# Mais de 5 anos    539
# 3 a 5 anos        215
# 1 a 3 anos        213
# Menos de 1 ano     33
#
# Admitidos nos últimos 12 meses : 38 funcionários
# Veteranos (5+ anos de casa)    : 534 funcionários
#
# Admissões por ano:
# Ano_Admissao
# 2015     33
# 2016     87
# 2017     99
# 2018     89
# 2019    101
# 2020     94
# 2021     94
# 2022    108
# 2023    106
# 2024    113
# 2025     76
#
# Salário médio:
#   Novos (últimos 12 meses): R$ 8,914.83
#   Veteranos (5+ anos)     : R$ 8,611.31

# %%
#*********************converter a coluna inteira de uma só vez de string em data (pd.to_datetime()):
# Antes da conversão:
print(f'Tipo ANTES : {df["Data_Admissao"].dtype}')
print(f'Valor antes: "{df["Data_Admissao"].iloc[0]}"')
# .iloc[0] → acessa a primeira linha pelo índice (iloc = integer location)

print()

# Converter a coluna inteira
# Trabalhamos em uma cópia para não alterar o df original
df_limpo = df.copy()
# .copy() → cria uma cópia independente
# Sem isso, mudanças em df_limpo afetariam o df original

df_limpo['Data_Admissao'] = pd.to_datetime(
    df_limpo['Data_Admissao'],
    format='%d/%m/%Y',  # formato da string de entrada
    errors='coerce'     # datas inválidas viram NaT (Not a Time) em vez de erro
)

print(f'Tipo DEPOIS: {df_limpo["Data_Admissao"].dtype}')
print(f'Valor depois: {df_limpo["Data_Admissao"].iloc[0]}')
print(f'NaT gerados : {df_limpo["Data_Admissao"].isna().sum()}')

# %%
#extraindo informações de data com o acessor .dt (o pandas libera somente após converter a coluna para datetime):

#PROPRIEDADES DE DATA:
#dt.year → ano
#dt.month → mês
#dt.day → dia
#dt.quarter → trimestre (1, 2, 3 ou 4)
#dt.weekday → dia da semana (0=segunda, 6=domingo)  
#dt.day_name() → nome do dia da semana (Segunda-feira, etc.)

# Criar colunas derivadas de data
df_limpo['Ano_Admissao'] = df_limpo['Data_Admissao'].dt.year
df_limpo['Mes_Admissao'] = df_limpo['Data_Admissao'].dt.month
df_limpo['Trimestre']    = df_limpo['Data_Admissao'].dt.quarter

# Calcular tempo de casa em anos
# pd.Timestamp.today() → data atual no formato do pandas
hoje_ts = pd.Timestamp.today()

df_limpo['Tempo_Casa_Anos'] = (
    (hoje_ts - df_limpo['Data_Admissao']).dt.days / 365.25
).round(1)
# Subtração de datas → timedelta
# .dt.days → extrai a diferença em dias
# / 365.25 → converte dias em anos
# .round(1) → arredonda para 1 casa decimal

# Ver o resultado
cols = ['Nome', 'Data_Admissao', 'Ano_Admissao', 'Mes_Admissao', 'Trimestre', 'Tempo_Casa_Anos']
df_limpo[cols].head(6)

# %%
#CRIANDO UMA FUNÇÃO: **************************

#def nome_da_funcao(parâmetros):
#    return

# exemplo #######################

# Função que classifica o tempo de casa em uma categoria de texto
# Por que criar isso? Categorias são mais fáceis de usar em gráficos
# e filtros no Power BI do que números decimais.

def classificar_tempo(anos):
    """
    Recebe: anos (número) — o tempo de casa do funcionário
    Retorna: uma categoria em texto
    """
    # pd.isna() verifica se o valor é nulo (NaN ou NaT)
    if pd.isna(anos):
        return 'Sem data'
    elif anos < 1:
        return 'Menos de 1 ano'
    elif anos < 3:
        return '1 a 3 anos'
    elif anos < 5:
        return '3 a 5 anos'
    else:
        return 'Mais de 5 anos'


# Testar a função com valores individuais antes de aplicar no DataFrame
print('Testando a função:')
print(f'  0.5 anos → "{classificar_tempo(0.5)}"')
print(f'  2.1 anos → "{classificar_tempo(2.1)}"')
print(f'  4.8 anos → "{classificar_tempo(4.8)}"')
print(f'  9.0 anos → "{classificar_tempo(9.0)}"')

# %%
# .apply(função) → aplica a função em cada linha da coluna
# É como fazer um loop em cada célula, mas de forma mais eficiente

df_limpo['Faixa_Tempo_Casa'] = df_limpo['Tempo_Casa_Anos'].apply(classificar_tempo)

print('Distribuição por faixa de tempo de casa:')
print(df_limpo['Faixa_Tempo_Casa'].value_counts())

# %%
#filtrando o dataframe por período de tempo (pd.DateOffset(years=_)):
hoje = pd.Timestamp.today()

# Definir os pontos de corte
um_ano_atras    = hoje - pd.DateOffset(years=1)
cinco_anos_atras = hoje - pd.DateOffset(years=5)

# Filtrar por período
# >= significa 'maior ou igual a' → admitidos depois de 1 ano atrás
novos     = df_limpo[df_limpo['Data_Admissao'] >= um_ano_atras]
veteranos = df_limpo[df_limpo['Data_Admissao'] <  cinco_anos_atras]

print(f'Admitidos nos últimos 12 meses : {len(novos)} funcionários')
print(f'Veteranos (5+ anos de casa)    : {len(veteranos)} funcionários')

print()

# Comparativo de salário: novos vs veteranos
print('Salário médio:')
print(f'  Novos     : R$ {novos["Salario"].mean():,.2f}')
print(f'  Veteranos : R$ {veteranos["Salario"].mean():,.2f}')

# Tempo médio de casa por departamento
media_depto = (
    df_limpo
    .groupby('Departamento')['Tempo_Casa_Anos']
    .mean()
    .round(1)
    .sort_values(ascending=False)
    .rename('Media_Anos')   # .rename() → renomeia a coluna resultante
    .reset_index()          # .reset_index() → converte o índice em coluna comum
)

print('Tempo médio de casa por departamento:')
print(media_depto.to_string(index=False))

# .idxmax() → retorna o NOME do índice com maior valor
maior = media_depto.set_index('Departamento')['Media_Anos'].idxmax()
menor = media_depto.set_index('Departamento')['Media_Anos'].idxmin()
print(f'\n→ Maior retenção: {maior}')
print(f'→ Menor retenção: {menor}')

# Admissões por ano — histórico completo
# .size() → conta o número de linhas em cada grupo
# .sort_index() → ordena pelo índice (neste caso, o ano)

por_ano = (
    df_limpo
    .groupby('Ano_Admissao')
    .size()
    .rename('Admissoes')
    .reset_index()
    .dropna()  # remove linhas com Ano_Admissao nulo
)

print('Admissões por ano:')
for _, row in por_ano.iterrows():
    # .iterrows() → itera linha por linha, retornando (índice, Series)
    # _ → descartamos o índice (convenção: _ = 'não preciso desse valor')
    barra = '█' * int(row['Admissoes'] / 5)
    print(f'  {int(row["Ano_Admissao"])}  {row["Admissoes"]:>4}  {barra}')

# %%
#agrupar linhas po colunas com "groupby" (df.groupby('coluna_agrupamento')['coluna_calculo'].função()):
# Salário médio por departamento
# .mean()             → calcula a média de cada grupo
# .round(2)           → arredonda para 2 casas
# .sort_values(...)   → ordena do maior para o menor
# ascending=False     → decrescente (False = do maior para o menor)

print('Salário médio por departamento:')
print(
    df_limpo.groupby('Departamento')['Salario']
    .mean()
    .round(2)
    .sort_values(ascending=False)
)

# %%
#SALVANDO O DATAFRAME LIMPO E ENRIQUECIDO: ******************************************
# Salvar o DataFrame enriquecido
# encoding='utf-8-sig' → UTF-8 com BOM — necessário para o Excel no Windows
#                         abrir o arquivo sem distorcer ã, é, ç

df_limpo.to_csv(
    'base_rh_dia01.csv',
    index=False,         # não salva o índice numérico como coluna extra
    sep=';',             # separador ponto-e-vírgula
    encoding='utf-8-sig'
)

print('✓ base_rh_dia01.csv salvo!')
print(f'  Colunas finais: {df_limpo.columns.tolist()}')
print(f'  Linhas        : {len(df_limpo)}')

#podemos exportar também para Excel, JSON, etc usando os métodos já vistos anteriormente

# %% [markdown]
# EXERCÍCIO FINAL
#
# **1.** Carregue o `base_rh.csv` com os parâmetros corretos e confirme que `Salario` é `float64`.
#
# **2.** Use `df.info()` e `df.describe()` para fazer o diagnóstico. Anote em uma célula Markdown:
# → *"Os 3 problemas mais importantes que encontrei foram..."*
#
# **3.** Converta `Data_Admissao` para datetime. Crie as colunas:
# `Ano_Admissao`, `Mes_Admissao`, `Tempo_Casa_Anos` e `Faixa_Tempo_Casa`.
#
# **4.** Responda com `groupby`:
# → Qual departamento tem a **maior** média de tempo de casa?
# → Qual tem a **menor**?
#
# **5.** Exporte `base_rh_deptos.xlsx` com uma aba `'Completo'` e mais uma aba por departamento.
#
# **6.** Faça o commit:
# ```bash
# git pull origin master
# git add alunos/seunome/
# git commit -m "semana 04 - dia 01: entrega arquivos e datetime"
# git push origin master
# git log --oneline -3
# ```
# Cole o resultado do `git log` na última célula do notebook.

# %%
#1. ************************************************************************************************************************************
#importar biblioteca pandas e abrir o arquivo csv:
import pandas as pd

caminho_local = r"C:\Users\DELL\OneDrive\Documentos\MH\SCTec\turma-visualizacao-de-dados\alunos\maria_helena\Semana04\base_rh.csv"

df = pd.read_csv(caminho_local, sep=";", encoding="cp1252", decimal=",")

#verificar o tipo de dato inserido na coluna "Salario":
print(f"Tipo da coluna Salario: {df['Salario'].dtype}")

#2. *************************************************************************************************************************************
print(df.info())
print(df.describe().round(2))

# OBSERVAÇÕES: i. Não há valores nulos na base de dados;
#              ii. Os dados constantes na coluna "Data_Admissao" são do tipo string, sendo necessário o seu tratamento;
#              iii. Será necessário tratar o dataframe e criar um novo arquivo para iniciar a análise dos dados.

#3. **************************************************************************************************************************************

#importar biblioteca datetime para trabalhar com datas:
from datetime import datetime, timedelta

#transformar string em datatime:
data_texto = '13/08/2024' #exemplo

#definir a formatação datetime:
data_obj = datetime.strptime(data_texto, '%d/%m/%Y')

#converter a coluna inteira de string em datetime:
#antes da conversão:
print(f'Tipo ANTES : {df["Data_Admissao"].dtype}')
print(f'Valor antes: "{df["Data_Admissao"].iloc[0]}"')

print()

#trabalhar em uma cópia para não alterar o dataframe original:
df_limpo = df.copy()

df_limpo['Data_Admissao'] = pd.to_datetime(
    df_limpo['Data_Admissao'],
    format='%d/%m/%Y',  # formato da string de entrada
    errors='coerce'     # datas inválidas viram NaT (Not a Time) em vez de erro
)

print(f'Tipo DEPOIS: {df_limpo["Data_Admissao"].dtype}')
print(f'Valor depois: {df_limpo["Data_Admissao"].iloc[0]}')
print(f'NaT gerados : {df_limpo["Data_Admissao"].isna().sum()}')

#criar colunas derivadas de data:
df_limpo['Ano_Admissao'] = df_limpo['Data_Admissao'].dt.year
df_limpo['Mes_Admissao'] = df_limpo['Data_Admissao'].dt.month

#calcular tempo de casa em anos:
hoje_ts = pd.Timestamp.today()

df_limpo['Tempo_Casa_Anos'] = (
    (hoje_ts - df_limpo['Data_Admissao']).dt.days / 365.25
).round(1)

#ver o resultado
cols = ['Nome', 'Data_Admissao', 'Ano_Admissao', 'Mes_Admissao', 'Tempo_Casa_Anos']
df_limpo[cols].head(6)

#criar coluna "Faixa_tempo_casa":
def classificar_tempo(anos):
    
    if pd.isna(anos):
        return 'Sem data'
    elif anos < 1:
        return 'Menos de 1 ano'
    elif anos < 3:
        return '1 a 3 anos'
    elif anos < 5:
        return '3 a 5 anos'
    else:
        return 'Mais de 5 anos'


print('Testando a função:')
print(f'  0.5 anos → "{classificar_tempo(0.5)}"')
print(f'  2.1 anos → "{classificar_tempo(2.1)}"')
print(f'  4.8 anos → "{classificar_tempo(4.8)}"')
print(f'  9.0 anos → "{classificar_tempo(9.0)}"')

df_limpo['Faixa_Tempo_Casa'] = df_limpo['Tempo_Casa_Anos'].apply(classificar_tempo)

print('Distribuição por faixa de tempo de casa:')
print(df_limpo['Faixa_Tempo_Casa'].value_counts())

#4. **************************************************************************************************************************************

#calcular tempo médio de casa por departamento:
medias_depto = df.groupby("Departamento")["Tempo_Casa_Anos"].mean()
relacao_medias = medias_depto.sort_values(ascending=False)

print(relacao_medias)

#verificar a maior media:
maior_media = relacao_medias.iloc[0]

#verificar a menor media:
menor_media = relacao_medias.iloc[0]

print(f"O Departamento com maior tempo de Casa é: {maior_depto} (média {maior_valor:.2f} anos)")
print(f"O Departamento com menor tempo de Casa é: {menor_depto} (média {menor_valor:.2f} anos)")
# Out:
# Departamento
# RH            5.804819
# Vendas        5.661250
# TI            5.525170
# Produção      5.502198
# Logística     5.326923
# Financeiro    5.136508
# Name: Tempo_Casa_Anos, dtype: float64
# O Departamento com maior tempo de Casa é: RH (média 5.80 anos)
# O Departamento com menor tempo de Casa é: Financeiro (média 5.14 anos)
