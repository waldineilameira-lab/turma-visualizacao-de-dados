# %%
import pandas as pd
import re
from datetime import datetime

print('✓ pandas versão:', pd.__version__)
print('✓ Bibliotecas importadas com sucesso!')
# Out:
# ✓ pandas versão: 3.0.2
# ✓ Bibliotecas importadas com sucesso!

# %%
df = pd.read_csv('base_rh.csv')

print(df)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 df = pd.read_csv('base_rh.csv')
#       2
#       3 print(df)
#
# File c:\Users\Milla\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\io\parsers\readers.py:873, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, skip_blank_lines, parse_dates, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     861 kwds_defaults = _refine_defaults_read(
#     862     dialect,
#     863     delimiter,
# ...

# %%
import pandas as pd

CAMINHO = 'base_rh.csv'

df = pd.read_csv(
    CAMINHO,
    sep=';',
    encoding='cp1252',
    decimal=','
)

print('✓ Arquivo lido com sucesso!')
print(f'Total de linhas: {df.shape[0]}')
print(f'Total de colunas: {df.shape[1]}')
# Out:
# ---------------------------------------------------------------------------
# EmptyDataError                            Traceback (most recent call last)
# Cell In[3], line 5
#       1 import pandas as pd
#       2
#       3 CAMINHO = 'base_rh.csv'
#       4
# ----> 5 df = pd.read_csv(
#       6     CAMINHO,
#       7     sep=';',
#       8     encoding='cp1252',
#
# ...

# %%
import pandas as pd

# O 'r' antes das aspas ajuda o Python a ler caminhos de pasta sem erro
CAMINHO = 'COLE_O_CAMINHO_DO_COLAB_AQUI' 

df = pd.read_csv(
    CAMINHO,
    sep=';',           
    encoding='cp1252', 
    decimal=','        
)

print('✓ Arquivo lido com sucesso!')
# Exibindo o tamanho da tabela
print(f'Total de funcionários: {df.shape[0]}')
print(f'Total de informações por funcionário: {df.shape[1]}')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[4], line 6
#       2
#       3 # O 'r' antes das aspas ajuda o Python a ler caminhos de pasta sem erro
#       4 CAMINHO = 'COLE_O_CAMINHO_DO_COLAB_AQUI'
#       5
# ----> 6 df = pd.read_csv(
#       7     CAMINHO,
#       8     sep=';',
#       9     encoding='cp1252',
#
# ...
