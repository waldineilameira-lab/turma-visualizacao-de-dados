# %%
import pandas as pd
import re   
from datetime import datetime

# %%
CAMINHO = r"C:\Users\PICHAU\Documents\Ruan\SCTEC\Aula\turma-visualizacao-de-dados\alunos\ruan.fernandes\semana.04\base_rh.csv"

df = pd.read_csv(
    CAMINHO,
    sep=";",
    encoding= 'cp1252', 
    decimal=','
)

print('Dados carregados com sucesso!')
print(f'total de linhas: {df.shape[0]}')
# Out:
# Dados carregados com sucesso!
# total de linhas: 1000

# %%
# df.tail(n)  # para mostrar as últimas n linhas do DataFrame
# Serve para confirmar se os dados foram carregados corretamente, e para ter uma ideia de como os dados estão estruturados.
# SE o arquivo tiver 1000 linhas, o tail deve mostras os IDS de (proximos de mil), comfirmando que os dados foram carregados corretamente.
df.tail(10)
# Out:
#      ID_Funcionario                  Nome Departamento        Cargo   Salario  \
# 990             991  Sr. Vicente Silveira     Produção      Gerente   8026.70
# 991             992       Emanuel da Cruz    Logística      Gerente  12572.11
# 992             993       Enrico Monteiro           RH  Coordenador  14677.33
# 993             994     Ana Lívia Cardoso           RH  Coordenador  14912.48
# 994             995     Fernando Monteiro           RH   Assistente  10983.02
# 995             996        Matheus Aragão   Financeiro     Analista  11389.03
# 996             997          Ryan Martins   Financeiro     Analista  14060.42
# 997             998     Isabelly Ferreira           TI      Gerente   2348.73
# 998             999         Thales Farias     Produção     Analista   9430.62
# 999            1000    Sra. Maysa Costela     Produção      Técnico  12549.72
#
#     Data_Admissao Genero  Idade Estado_Civil   Status
# 990    11/07/2021      F     55        Viúvo  Inativo
# ...

# %%
#df.columns  # para mostrar os nomes das colunas do DataFrame

print('Colunas do dataset:')
print(df.columns.tolist())
# Out:
# Colunas do dataset:
# ['ID_Funcionario', 'Nome', 'Departamento', 'Cargo', 'Salario', 'Data_Admissao', 'Genero', 'Idade', 'Estado_Civil', 'Status']

# %% [markdown]
# Diagnóstico: Tipos e nulos
#
# O que são tipos de dados ?
# Cada coluba armazena um tipo de informação. O pythoon precisa  saber o tipo
# para saber o que pode fazer
#
#
#
# O que são nulos ?
# São celulas vazias -  o campo não foi

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   ID_Funcionario  1000 non-null   int64
#  1   Nome            1000 non-null   str
#  2   Departamento    1000 non-null   str
#  3   Cargo           1000 non-null   str
#  4   Salario         1000 non-null   float64
#  5   Data_Admissao   1000 non-null   str
#  6   Genero          1000 non-null   str
#  7   Idade           1000 non-null   int64
#  8   Estado_Civil    1000 non-null   str
#  9   Status          1000 non-null   str
# dtypes: float64(1), int64(2), str(7)
# memory usage: 78.3 KB

# %%
df.isnull()
# Out:
#      ID_Funcionario   Nome  Departamento  Cargo  Salario  Data_Admissao  \
# 0             False  False         False  False    False          False
# 1             False  False         False  False    False          False
# 2             False  False         False  False    False          False
# 3             False  False         False  False    False          False
# 4             False  False         False  False    False          False
# ..              ...    ...           ...    ...      ...            ...
# 995           False  False         False  False    False          False
# 996           False  False         False  False    False          False
# 997           False  False         False  False    False          False
# 998           False  False         False  False    False          False
# 999           False  False         False  False    False          False
#
#      Genero  Idade  Estado_Civil  Status
# 0     False  False         False   False
# ...

# %%
print ('Número de valores nulos por coluna:')
print(df.isnull().sum())
# Out:
# Número de valores nulos por coluna:
# ID_Funcionario    0
# Nome              0
# Departamento      0
# Cargo             0
# Salario           0
# Data_Admissao     0
# Genero            0
# Idade             0
# Estado_Civil      0
# Status            0
# dtype: int64
