# %%
Endereço = {
    "rua": "Rua das Flores",
    "numero": 123,
    "bairro": "Jardim Primavera",
    "cidade": "São Paulo",
    "estado": "SP",
    "cep": "01234-567"
}

print(Endereço)
# Out:
# {'rua': 'Rua das Flores', 'numero': 123, 'bairro': 'Jardim Primavera', 'cidade': 'São Paulo', 'estado': 'SP', 'cep': '01234-567'}

# %%
{
    "nome": "Ruan Fernandes",
    "idade": 25,
    "email": "ruan.fernandes@example.com"
}
# Out:
# {'nome': 'Ruan Fernandes', 'idade': 25, 'email': 'ruan.fernandes@example.com'}
