# %%
'''
re.search()         # procura um padrão
re.findall()        # retorna tudo que encontrou
re.sub()            # substitui texto por outro
re.match()          # verifica começo da string
re.split()          # divide a string (texto) em partes.
'''


import pandas as pd
import re

URL = (
    "https://raw.githubusercontent.com/"
    "cfneves/turma-visualizacao-de-dados/"
    "master/aulas/semana_04/base_rh.csv"
)
