# %% [markdown]
# # Programa de OCR
# O programa recebe um conjunto de pdf e le cada pagina buscando um item especifico delimitado pela(s) area(s)

# %% [markdown]
# ## Passo 1: Receber arquivos
# Pedir para selecioar arquivos

# %% [markdown]
# # Configurar

# %% [markdown]
# # Saida
